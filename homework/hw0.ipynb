# %%
a = []
while True:
    b = input()
    if b == '.':
        break
    a.append(b)
a.sort()
print(a)
while a:
    c = input()
    if c in a:
        a.remove(c)
        print(a)
    else:
        print("Город не найден в списке.")

print("Список городов пуст. Программа завершена.")
# Out:
# ['Балахна', 'Москва', 'Нижний Новгород', 'Петербург']
# Город не найден в списке.
# Город не найден в списке.
# ['Балахна', 'Нижний Новгород', 'Петербург']
# ['Балахна', 'Нижний Новгород']
# ['Нижний Новгород']
# []
# Список городов пуст. Программа завершена.
