# %%
import pandas as pd
import random

df = pd.read_excel('../03_all_cities.xlsx', sheet_name='cities')

# Список городов
goroda = df['city']

# %%
all_letters = list('АБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ')
start_dict = {}
for letter in all_letters:
    start_dict[letter] = set()
for city in goroda:
    l = city[0].upper()
    if l in start_dict:
        start_dict[l].add(city)
r = random.choice(city)
print(r)

g = random.choice(all_letters)
while len(start_dict[g[-1].upper()]) == 0:
    g = g[:-1]
print("Начинаем на букву "+ g)
while g != ".":
    gg = random.choice(list(start_dict[g[-1].upper()]))
    print(gg)
    g1 = gg[-1].upper()
    if g1 not in start_dict:
        g1 = gg[-2].upper()
    g = input("Введите город на букву "+ g1)
    if g[0].upper() != g1:
        print("Вы ввели город на другую букву. Вы проиграли")
        break
    while len(start_dict[g[-1].upper()]) == 0:
        g = g[:-1]
# Out:
# л
# Начинаем на букву Л
# Лаборем
# Введите город на букву М Морёльь
# Лядинки (Наговское с/п)
# Введите город на букву П Пыльъь
# Лепёшки
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 22
#      20 if g1 not in start_dict:
#      21     g1 = gg[-2].upper()
# ---> 22 g = input("Введите город на букву "+ g1)
#      23 if g[0].upper() != g1:
#      24     print("Вы ввели город на другую букву. Вы проиграли")
#
# File ~/git/goroda/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/git/goroda/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
